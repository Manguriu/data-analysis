# %% [markdown]
# <a href="https://colab.research.google.com/github/Manguriu/data-analysis/blob/main/Untitled65.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/E0.csv')
# Out:
#     Div        Date   Time     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  11/08/2023  20:00      Burnley       Man City     0     3   A     0
# 1    E0  12/08/2023  12:30      Arsenal  Nott'm Forest     2     1   H     2
# 2    E0  12/08/2023  15:00  Bournemouth       West Ham     1     1   D     0
# 3    E0  12/08/2023  15:00     Brighton          Luton     4     1   H     1
# 4    E0  12/08/2023  15:00      Everton         Fulham     0     1   A     0
# ..   ..         ...    ...          ...            ...   ...   ...  ..   ...
# 278  E0  13/03/2024  19:30  Bournemouth          Luton     4     3   H     0
# 279  E0  16/03/2024  15:00      Burnley      Brentford     2     1   H     1
# 280  E0  16/03/2024  15:00        Luton  Nott'm Forest     1     1   D     0
# 281  E0  16/03/2024  17:30       Fulham      Tottenham     3     0   H     1
# 282  E0  17/03/2024  14:00     West Ham    Aston Villa     1     1   D     1
#
# ...

# %%
df_premier21 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/E0.csv')

# %%
df_premier21
# Out:
#     Div        Date   Time     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  11/08/2023  20:00      Burnley       Man City     0     3   A     0
# 1    E0  12/08/2023  12:30      Arsenal  Nott'm Forest     2     1   H     2
# 2    E0  12/08/2023  15:00  Bournemouth       West Ham     1     1   D     0
# 3    E0  12/08/2023  15:00     Brighton          Luton     4     1   H     1
# 4    E0  12/08/2023  15:00      Everton         Fulham     0     1   A     0
# ..   ..         ...    ...          ...            ...   ...   ...  ..   ...
# 278  E0  13/03/2024  19:30  Bournemouth          Luton     4     3   H     0
# 279  E0  16/03/2024  15:00      Burnley      Brentford     2     1   H     1
# 280  E0  16/03/2024  15:00        Luton  Nott'm Forest     1     1   D     0
# 281  E0  16/03/2024  17:30       Fulham      Tottenham     3     0   H     1
# 282  E0  17/03/2024  14:00     West Ham    Aston Villa     1     1   D     1
#
# ...

# %%
#renaming column names
df_premier21.rename(columns = {'FTHG': 'home_goals',
                              'FTAG':'Away_goals'}, inplace=True)

# %%
df_premier21
# Out:
#     Div        Date   Time     HomeTeam       AwayTeam  home_goals  \
# 0    E0  11/08/2023  20:00      Burnley       Man City           0
# 1    E0  12/08/2023  12:30      Arsenal  Nott'm Forest           2
# 2    E0  12/08/2023  15:00  Bournemouth       West Ham           1
# 3    E0  12/08/2023  15:00     Brighton          Luton           4
# 4    E0  12/08/2023  15:00      Everton         Fulham           0
# ..   ..         ...    ...          ...            ...         ...
# 278  E0  13/03/2024  19:30  Bournemouth          Luton           4
# 279  E0  16/03/2024  15:00      Burnley      Brentford           2
# 280  E0  16/03/2024  15:00        Luton  Nott'm Forest           1
# 281  E0  16/03/2024  17:30       Fulham      Tottenham           3
# 282  E0  17/03/2024  14:00     West Ham    Aston Villa           1
#
#      Away_goals FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# 0             3   A     0     2  ...     2.28  1.50      1.95      1.98
# ...
